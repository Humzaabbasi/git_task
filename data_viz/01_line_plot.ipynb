# %% [markdown]
# # Import Libraries
# - Seaborn automatically install this libraries
# *numpy*
# *scipy*
# *pandas*
# *matplotlib*

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt
#Load_data_set
flower=sns.load_dataset("iris")
flower
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#draw a line plot
sns.lineplot(x="sepal_length",y="sepal_width",data=flower)
plt.title("Draw Line Plot")
plt.show()

# %%
## -Adiing Title

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt
#Load_data_set
flower=sns.load_dataset("iris")
#flower
#draw a line plot
sns.lineplot(x="sepal_length",y="sepal_width",data=flower)
plt.title("Title: Flowers Line Plot")
plt.show()

# %%
## - Adding X-Limits and Y-Limits

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt
#Load_data_set
flower=sns.load_dataset("iris")
#flower
#draw a line plot
sns.lineplot(x="sepal_length",y="sepal_width",data=flower)
plt.title("set X and Y limits")
plt.xlim(2)
plt.ylim(1)
plt.show()

# %% [markdown]
# ## set styles
# - Darkgrid
# - Whitegrid
# - Dark
# - White
# - Ticks

# %%
# # set styles
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#Load_data_set
flower=sns.load_dataset("iris")
plt.figure(figsize=(8,6))
#flower
#draw a line plot
sns.lineplot(x="sepal_length",y="sepal_width",data=flower)
plt.title("set X and Y limits")
#sns.set(style="ticks", context="talk")
sns.set_style("dark")
sns.set_style(style=None,rc=None)
plt.show()

# %%
# %matplotlib inline
# import seaborn as sns
# import matplotlib.pyplot as plt
# sns.set(style="ticks", context="talk")
# plt.style.use("dark_background")
# df = sns.load_dataset("anscombe")
# sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
#            col_wrap=2, ci=None, palette="pastel", size=4,
#            scatter_kws={"s": 50, "alpha": 1})

# %%
## - Figure size

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt
#Load_data_set
flower=sns.load_dataset("iris")
plt.figure(figsize=(8,6))
#flower
#draw a line plot
sns.lineplot(x="sepal_length",y="sepal_width",data=flower)
plt.title("set fig size")

plt.show()

# %%
# bar_plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
kashti=sns.load_dataset("titanic")
kashti
sns.barplot(x="class",y="fare",data=kashti,
           linewidth=3,facecolor =(0,0,0,0),
               errcolor=(".5"),edgecolor=("0"))
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>
